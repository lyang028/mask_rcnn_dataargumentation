# %% [markdown]
# <a href="https://colab.research.google.com/github/lyang028/mask_rcnn_dataargumentation/blob/master/mask_rcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Initialize (link google drive)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# clone project from github

# %%
# !git clone https://github.com/lyang028/mask_rcnn_dataargumentation.git

# %% [markdown]
# Training function

# %%
# %cd mask_rcnn_dataargumentation/
# !python workers_keep_train.py

# %% [markdown]
# Test function

# %%
# %cd mask_rcnn_dataargumentation/
# !python predition.py

# %%
# %cd ..
# !ls

# %%
# %cd mask_rcnn_dataargumentation/
# !python test.py test test

# %% [markdown]
# **Calculate entropy**

# %%
# !pip install opencv-python

# %%
# %cd content

# %% [markdown]
# Calculate wd

# %%
# %cd mask_rcnn_dataargumentation/
# !python detect_layer_inner_structure.py

# %%
# %cd ../drive/My Drive/silhouette_weight/logs/worker20200112T0054/
# !ls
